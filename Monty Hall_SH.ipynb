# %% [markdown]
# # Random door selection

# %%
import random

doors = ['yellow', 'red', 'blue']

print(random.choice(doors))
# Out:
# blue

# %% [markdown]
# Random colour picked for a door

# %%
for i in range(100):
    print(random.choice(doors))
# Out:
# yellow
# blue
# yellow
# blue
# red
# red
# yellow
# yellow
# red
# red
# yellow
# red
# yellow
# yellow
# yellow
# blue
# red
# red
# yellow
# blue
# yellow
# blue
# yellow
# red
# blue
# blue
# red
# yellow
# blue
# blue
# red
# yellow
# blue
# blue
# red
# yellow
# red
# red
# blue
# red
# yellow
# blue
# blue
# blue
# red
# yellow
# yellow
# yellow
# red
# blue
# yellow
# blue
# blue
# red
# yellow
# yellow
# yellow
# yellow
# blue
# red
# yellow
# red
# red
# yellow
# red
# blue
# yellow
# blue
# red
# red
# blue
# blue
# yellow
# yellow
# yellow
# blue
# blue
# yellow
# blue
# red
# red
# red
# blue
# blue
# blue
# blue
# blue
# yellow
# red
# red
# red
# blue
# yellow
# blue
# blue
# yellow
# yellow
# red
# blue
# blue

# %%
tenthous = [random.choice(doors) for i in range(10000)]

tenthous
# Out:
# ['yellow',
#  'red',
#  'red',
#  'blue',
#  'yellow',
#  'yellow',
#  'red',
#  'red',
#  'red',
#  'yellow',
#  'yellow',
#  'yellow',
#  'yellow',
#  'blue',
#  'red',
#  'red',
#  'red',
#  'yellow',
#  'blue',
#  'blue',
#  'red',
#  'yellow',
#  'yellow',
#  'red',
#  'blue',
#  'red',
#  'red',
#  'blue',
#  'red',
#  'blue',
#  'red',
#  'blue',
#  'blue',
#  'blue',
#  'blue',
#  'yellow',
#  'red',
#  'blue',
#  'red',
#  'red',
#  'red',
#  'red',
#  'blue',
#  'blue',
#  'yellow',
#  'yellow',
#  'blue',
#  'yellow',
#  'yellow',
#  'red',
#  'yellow',
#  'red',
#  'yellow',
#  'blue',
#  'red',
#  'red',
#  'blue',
#  'yellow',
#  'red',
#  'yellow',
#  'blue',
#  'yellow',
#  'blue',
#  'blue',
#  'red',
#  'blue',
#  'blue',
#  'red',
#  'red',
#  'yellow',
#  'yellow',
#  'blue',
#  'blue',
#  'red',
#  'red',
#  'blue',
#  'red',
#  'blue',
#  'blue',
#  'yellow',
#  'blue',
#  'red',
#  'red',
#  'blue',
#  'blue',
#  'yellow',
#  'red',
#  'yellow',
#  'blue',
#  'yellow',
#  'blue',
#  'yellow',
#  'red',
#  'blue',
#  'blue',
#  'yellow',
#  'blue',
#  'blue',
#  'red',
#  'blue',
#  'yellow',
#  'red',
#  'blue',
#  'red',
#  'yellow',
#  'red',
#  'red',
#  'yellow',
#  'blue',
#  'blue',
#  'yellow',
#  'blue',
#  'red',
#  'red',
#  'red',
#  'red',
#  'blue',
#  'red',
#  'red',
#  'blue',
#  'red',
#  'red',
#  'blue',
#  'yellow',
#  'red',
#  'blue',
#  'blue',
#  'blue',
#  'blue',
#  'yellow',
#  'red',
#  'blue',
#  'blue',
#  'yellow',
#  'blue',
#  'red',
#  'red',
#  'red',
#  'red',
#  'yellow',
#  'blue',
#  'blue',
#  'yellow',
#  'blue',
#  'blue',
#  'blue',
#  'yellow',
#  'blue',
#  'blue',
#  'blue',
#  'blue',
#  'red',
#  'yellow',
#  'yellow',
#  'yellow',
#  'red',
#  'red',
#  'red',
#  'yellow',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'yellow',
#  'yellow',
#  'yellow',
#  'blue',
#  'blue',
#  'blue',
#  'blue',
#  'blue',
#  'yellow',
#  'yellow',
#  'blue',
#  'yellow',
#  'red',
#  'blue',
#  'yellow',
#  'blue',
#  'yellow',
#  'yellow',
#  'yellow',
#  'red',
#  'yellow',
#  'yellow',
#  'red',
#  'red',
#  'yellow',
#  'blue',
#  'yellow',
#  'blue',
#  'red',
#  'blue',
#  'yellow',
#  'blue',
#  'blue',
#  'yellow',
#  'blue',
#  'yellow',
#  'blue',
#  'red',
#  'yellow',
#  'blue',
#  'yellow',
#  'blue',
#  'yellow',
#  'yellow',
#  'yellow',
#  'yellow',
#  'blue',
#  'yellow',
#  'blue',
#  'red',
#  'blue',
#  'red',
#  'yellow',
#  'yellow',
#  'yellow',
#  'yellow',
#  'red',
#  'red',
#  'yellow',
#  'blue',
#  'blue',
#  'blue',
#  'blue',
#  'blue',
#  'yellow',
#  'red',
#  'blue',
#  'blue',
#  'blue',
#  'yellow',
#  'red',
#  'blue',
#  'blue',
#  'blue',
#  'red',
#  'blue',
#  'blue',
#  'blue',
#  'yellow',
#  'yellow',
#  'red',
#  'yellow',
#  'blue',
#  'blue',
#  'red',
#  'red',
#  'red',
#  'blue',
#  'blue',
#  'blue',
#  'blue',
#  'yellow',
#  'red',
#  'red',
#  'yellow',
#  'yellow',
#  'red',
#  'red',
#  'yellow',
#  'red',
#  'yellow',
#  'yellow',
#  'yellow',
#  'yellow',
#  'red',
#  'blue',
#  'yellow',
#  'red',
#  'red',
#  'yellow',
#  'red',
#  'yellow',
#  'blue',
#  'red',
#  'yellow',
#  'yellow',
#  'yellow',
#  'red',
#  'blue',
#  'yellow',
#  'red',
#  'blue',
#  'red',
#  'blue',
#  'yellow',
#  'red',
#  'yellow',
#  'red',
#  'yellow',
#  'yellow',
#  'blue',
#  'red',
#  'yellow',
#  'blue',
#  'yellow',
#  'red',
#  'blue',
#  'red',
#  'yellow',
#  'red',
#  'yellow',
#  'blue',
#  'blue',
#  'blue',
#  'blue',
#  'red',
#  'yellow',
#  'blue',
#  'blue',
#  'yellow',
#  'blue',
#  'yellow',
#  'red',
#  'blue',
#  'blue',
#  'red',
#  'yellow',
#  'yellow',
#  'red',
#  'yellow',
#  'red',
#  'blue',
#  'yellow',
#  'blue',
#  'blue',
#  'red',
#  'blue',
#  'red',
#  'blue',
#  'blue',
#  'red',
#  'blue',
#  'red',
#  'yellow',
#  'blue',
#  'yellow',
#  'red',
#  'yellow',
#  'red',
#  'blue',
#  'yellow',
#  'blue',
#  'blue',
#  'red',
#  'red',
#  'red',
#  'red',
#  'blue',
#  'yellow',
#  'blue',
#  'red',
#  'yellow',
#  'yellow',
#  'red',
#  'yellow',
#  'yellow',
#  'blue',
#  'red',
#  'blue',
#  'yellow',
#  'yellow',
#  'red',
#  'blue',
#  'blue',
#  'yellow',
#  'blue',
#  'red',
#  'blue',
#  'red',
#  'yellow',
#  'red',
#  'blue',
#  'blue',
#  'blue',
#  'blue',
#  'yellow',
#  'yellow',
#  'blue',
#  'yellow',
#  'red',
#  'blue',
#  'blue',
#  'yellow',
#  'red',
#  'red',
#  'yellow',
#  'yellow',
#  'yellow',
#  'yellow',
#  'blue',
#  'yellow',
#  'blue',
#  'yellow',
#  'blue',
#  'yellow',
#  'yellow',
#  'yellow',
#  'yellow',
#  'blue',
#  'yellow',
#  'blue',
#  'yellow',
#  'red',
#  'blue',
#  'red',
#  'red',
#  'blue',
#  'red',
#  'yellow',
#  'yellow',
#  'yellow',
#  'red',
#  'yellow',
#  'yellow',
#  'blue',
#  'yellow',
#  'yellow',
#  'blue',
#  'yellow',
#  'blue',
#  'yellow',
#  'yellow',
#  'red',
#  'blue',
#  'red',
#  'blue',
#  'yellow',
#  'red',
#  'yellow',
#  'blue',
#  'yellow',
#  'yellow',
#  'red',
#  'blue',
#  'yellow',
#  'yellow',
#  'blue',
#  'blue',
#  'red',
#  'red',
#  'yellow',
#  'red',
#  'red',
#  'yellow',
#  'blue',
#  'yellow',
#  'red',
#  'red',
#  'red',
#  'yellow',
#  'blue',
#  'yellow',
#  'blue',
#  'red',
#  'yellow',
#  'blue',
#  'red',
#  'blue',
#  'yellow',
#  'yellow',
#  'yellow',
#  'yellow',
#  'red',
#  'red',
#  'red',
#  'blue',
#  'red',
#  'yellow',
#  'yellow',
#  'blue',
#  'blue',
#  'blue',
#  'yellow',
#  'yellow',
#  'yellow',
#  'blue',
#  'yellow',
#  'blue',
#  'yellow',
#  'blue',
#  'blue',
#  'blue',
#  'red',
#  'blue',
#  'blue',
#  'red',
#  'yellow',
#  'yellow',
#  'blue',
#  'red',
#  'red',
#  'red',
#  'red',
#  'blue',
#  'yellow',
#  'red',
#  'blue',
#  'red',
#  'red',
#  'yellow',
#  'blue',
#  'blue',
#  'red',
#  'red',
#  'blue',
#  'blue',
#  'yellow',
#  'blue',
#  'red',
#  'red',
#  'yellow',
#  'red',
#  'blue',
#  'blue',
#  'red',
#  'yellow',
#  'yellow',
#  'blue',
#  'red',
#  'blue',
#  'red',
#  'yellow',
#  'red',
#  'blue',
#  'red',
#  'yellow',
#  'yellow',
#  'yellow',
#  'red',
#  'red',
#  'yellow',
#  'blue',
#  'red',
#  'yellow',
#  'red',
#  'blue',
#  'red',
#  'red',
#  'red',
#  'blue',
#  'red',
#  'blue',
#  'red',
#  'red',
#  'blue',
#  'blue',
#  'yellow',
#  'yellow',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'blue',
#  'blue',
#  'red',
#  'blue',
#  'blue',
#  'red',
#  'yellow',
#  'red',
#  'blue',
#  'red',
#  'red',
#  'yellow',
#  'yellow',
#  'blue',
#  'yellow',
#  'yellow',
#  'red',
#  'yellow',
#  'blue',
#  'yellow',
#  'blue',
#  'yellow',
#  'blue',
#  'red',
#  'blue',
#  'yellow',
#  'yellow',
#  'yellow',
#  'yellow',
#  'blue',
#  'blue',
#  'yellow',
#  'yellow',
#  'red',
#  'blue',
#  'red',
#  'red',
#  'yellow',
#  'blue',
#  'yellow',
#  'yellow',
#  'red',
#  'yellow',
#  'blue',
#  'yellow',
#  'red',
#  'yellow',
#  'yellow',
#  'blue',
#  'yellow',
#  'red',
#  'blue',
#  'red',
#  'yellow',
#  'red',
#  'blue',
#  'red',
#  'red',
#  'blue',
#  'red',
#  'blue',
#  'red',
#  'blue',
#  'yellow',
#  'yellow',
#  'blue',
#  'blue',
#  'yellow',
#  'yellow',
#  'red',
#  'red',
#  'blue',
#  'blue',
#  'blue',
#  'yellow',
#  'yellow',
#  'blue',
#  'red',
#  'blue',
#  'yellow',
#  'blue',
#  'blue',
#  'yellow',
#  'red',
#  'blue',
#  'blue',
#  'blue',
#  'blue',
#  'yellow',
#  'red',
#  'blue',
#  'yellow',
#  'red',
#  'yellow',
#  'blue',
#  'blue',
#  'blue',
#  'red',
#  'blue',
#  'yellow',
#  'red',
#  'blue',
#  'blue',
#  'yellow',
#  'red',
#  'red',
#  'yellow',
#  'blue',
#  'blue',
#  'blue',
#  'red',
#  'red',
#  'blue',
#  'red',
#  'blue',
#  'blue',
#  'blue',
#  'blue',
#  'blue',
#  'blue',
#  'yellow',
#  'blue',
#  'yellow',
#  'yellow',
#  'red',
#  'blue',
#  'yellow',
#  'blue',
#  'red',
#  'yellow',
#  'blue',
#  'yellow',
#  'yellow',
#  'yellow',
#  'red',
#  'red',
#  'red',
#  'blue',
#  'yellow',
#  'yellow',
#  'blue',
#  'yellow',
#  'yellow',
#  'blue',
#  'yellow',
#  'red',
#  'yellow',
#  'blue',
#  'red',
#  'blue',
#  'red',
#  'yellow',
#  'red',
#  'red',
#  'blue',
#  'yellow',
#  'blue',
#  'yellow',
#  'blue',
#  'red',
#  'yellow',
#  'yellow',
#  'red',
#  'blue',
#  'blue',
#  'red',
#  'blue',
#  'blue',
#  'red',
#  'red',
#  'yellow',
#  'yellow',
#  'blue',
#  'yellow',
#  'red',
#  'yellow',
#  'yellow',
#  'yellow',
#  'yellow',
#  'red',
#  'yellow',
#  'yellow',
#  'red',
#  'blue',
#  'red',
#  'yellow',
#  'blue',
#  'blue',
#  'red',
#  'blue',
#  'red',
#  'blue',
#  'blue',
#  'yellow',
#  'blue',
#  'yellow',
#  'yellow',
#  'red',
#  'blue',
#  'blue',
#  'yellow',
#  'blue',
#  'red',
#  'yellow',
#  'blue',
#  'blue',
#  'red',
#  'yellow',
#  'red',
#  'red',
#  'red',
#  'yellow',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'blue',
#  'blue',
#  'red',
#  'blue',
#  'blue',
#  'yellow',
#  'red',
#  'blue',
#  'blue',
#  'red',
#  'red',
#  'red',
#  'red',
#  'yellow',
#  'yellow',
#  'blue',
#  'yellow',
#  'red',
#  'red',
#  'red',
#  'blue',
#  'red',
#  'blue',
#  'yellow',
#  'blue',
#  'yellow',
#  'red',
#  'blue',
#  'red',
#  'yellow',
#  'yellow',
#  'blue',
#  'blue',
#  'yellow',
#  'red',
#  'red',
#  'yellow',
#  'red',
#  'red',
#  'yellow',
#  'blue',
#  'yellow',
#  'red',
#  'blue',
#  'blue',
#  'blue',
#  'blue',
#  'yellow',
#  'yellow',
#  'red',
#  'blue',
#  'yellow',
#  'blue',
#  'blue',
#  'yellow',
#  'blue',
#  'yellow',
#  'yellow',
#  'blue',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'yellow',
#  'red',
#  'blue',
#  'blue',
#  'blue',
#  'blue',
#  'red',
#  'blue',
#  'yellow',
#  'blue',
#  'red',
#  'blue',
#  'red',
#  'red',
#  'blue',
#  'yellow',
#  'red',
#  'blue',
#  'red',
#  'yellow',
#  'yellow',
#  'red',
#  'yellow',
#  'yellow',
#  'red',
#  'yellow',
#  'red',
#  'yellow',
#  'yellow',
#  'yellow',
#  'yellow',
#  'yellow',
#  'yellow',
#  'yellow',
#  'yellow',
#  'red',
#  'blue',
#  'red',
#  'yellow',
#  'blue',
#  'red',
#  'blue',
#  'red',
#  'blue',
#  'red',
#  'red',
#  'yellow',
#  'red',
#  'red',
#  'yellow',
#  'blue',
#  'red',
#  'red',
#  'red',
#  'blue',
#  'blue',
#  'blue',
#  'red',
#  'red',
#  'red',
#  'yellow',
#  'blue',
#  'yellow',
#  'red',
#  'red',
#  'blue',
#  'red',
#  'blue',
#  'blue',
#  'red',
#  'red',
#  'red',
#  'yellow',
#  'yellow',
#  'yellow',
#  'blue',
#  'blue',
#  'blue',
#  'red',
#  'blue',
#  'red',
#  'yellow',
#  'red',
#  'yellow',
#  'blue',
#  'red',
#  'red',
#  'yellow',
#  'yellow',
#  'yellow',
#  'red',
#  'blue',
#  'blue',
#  'blue',
#  'red',
#  'red',
#  'red',
#  'red',
#  'blue',
#  'red',
#  'blue',
#  'yellow',
#  'yellow',
#  'red',
#  'blue',
#  'yellow',
#  'yellow',
#  'red',
#  'red',
#  'red',
#  'red',
#  'yellow',
#  'blue',
#  'red',
#  'yellow',
#  'blue',
#  'yellow',
#  'yellow',
#  'red',
#  'blue',
#  'blue',
#  'blue',
#  'blue',
#  'blue',
#  'red',
#  'yellow',
#  'red',
#  'blue',
#  'blue',
#  'blue',
#  'yellow',
#  'red',
#  'yellow',
#  'blue',
#  'blue',
#  'yellow',
#  'blue',
#  'blue',
#  'yellow',
#  'blue',
#  'blue',
#  'yellow',
#  'red',
#  'blue',
#  'blue',
#  'yellow',
#  'red',
#  'red',
#  'blue',
#  'blue',
#  'blue',
#  'yellow',
#  'blue',
#  'blue',
#  'yellow',
#  'blue',
#  'yellow',
#  'blue',
#  'yellow',
#  'blue',
#  ...]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10,6))
sns.set(style='darkgrid')
ax = sns.countplot(y=tenthous)
plt.show()
